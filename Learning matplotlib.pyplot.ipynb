# %%
# !pip install --upgrade pandas
# !pip install --upgrade pandas-datareader
# !pip install --upgrade matplotlib
# !pip install --upgrade yfinance
# !pip install --upgrade datetime
# Out:
# ...
#      ---------------------------------------- 10.9/10.9 MB 8.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.2
#     Uninstalling pandas-1.5.2:
#       Successfully uninstalled pandas-1.5.2
# ...

# %%
# !pip install --upgrade sklearn --use-pep517

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas_datareader as pdr

# %%
x = [7, 2, 3, 4, 5]
y = [0.75, 1, 1.5, 2, 2.5]
plt.stem(x, y)
plt.show()

# %%
x = [7, 2, 3, 4, 5]
y = [0.75, 1, 1.5, 2, 2.5]
plt.bar(x, y)
plt.show()

# %%
x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)
plt.plot(x, y)
plt.xlabel('Angle')
plt.ylabel('Sine')
plt.title('SineWave')
plt.show()

# %%
x = pylab.linspace(-3, 3, 30)
y = x**2
plt.plot(x, y)
plt.show()

# %%
df = pd.read_excel('Vendas.xlsx', sheet_name=[0])

print(df)

# %%
import openpyxl as opxl

wb = opxl.Workbook()

ws = wb.active

ws['A1'] = 21
ws['B1'] = 22
ws['C1'] = 23
ws['D1'] = 24
ws.append([1, 2, 3, 4, 5])
ws['A2'] = dt.datetime.now()

wb.save('sample.xlsx')

# %%
wb = opxl.load_workbook('sample.xlsx')
print(wb.sheetnames)
display(ws.cell(row=1, column=2))
# Out:
# ['Sheet']
# <Cell 'Sheet'.B1>

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 get_ipython().system('jt -l')
# ----> 2 dir(jupyterthemes)
#
# NameError: name 'jupyterthemes' is not defined

# %%
# !jt -t gruvboxd -f source -fs 10 -nfs 9 -tfs 9
